# %%
import matplotlib.pyplot as plt

# Define steps and corresponding metrics
steps = ["Dummy", "KNN Training", "KNN Prediction", "KNN Retraining", "KNN Retrained Prediction"]
accuracy =    [0.51, 0.73, 0.70, 0.76, 0.79]
precision =   [0.48, 0.72, 0.69, 0.75, 0.78]
recall =      [0.50, 0.74, 0.71, 0.77, 0.80]

# Plot the lines
plt.figure(figsize=(10, 6))
plt.plot(steps, accuracy, label='Accuracy', marker='o')
plt.plot(steps, precision, label='Precision', marker='s')
plt.plot(steps, recall, label='Recall', marker='^')

plt.title("Batch Model Performance Across Steps")
plt.xlabel("Modeling Phase")
plt.ylabel("Metric Score")
plt.ylim(0.4, 1.0)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Week 10 - Batch Model Performance

# %% [markdown]
# # HarithaThipparapu

# %% [markdown]
# ## Week 10 - Batch Model Performance

# %% [markdown]
# #### Create a Graph Demonstrating Steps in Batch Model Performance
#
# will simulate the five steps:
#
# * Dummy Classifier
#
# * KNN Training
#
# * KNN Prediction
#
# * KNN Retraining
#
# * KNN Retrained Prediction

# %%
import matplotlib.pyplot as plt

# Define steps and corresponding metrics
steps = ["Dummy", "KNN Training", "KNN Prediction", "KNN Retraining", "KNN Retrained Prediction"]
accuracy =    [0.51, 0.73, 0.70, 0.76, 0.79]
precision =   [0.48, 0.72, 0.69, 0.75, 0.78]
recall =      [0.50, 0.74, 0.71, 0.77, 0.80]

# Plot the lines
plt.figure(figsize=(10, 6))
plt.plot(steps, accuracy, label='Accuracy', marker='o')
plt.plot(steps, precision, label='Precision', marker='s')
plt.plot(steps, recall, label='Recall', marker='^')

plt.title("Batch Model Performance Across Steps")
plt.xlabel("Modeling Phase")
plt.ylabel("Metric Score")
plt.ylim(0.4, 1.0)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
